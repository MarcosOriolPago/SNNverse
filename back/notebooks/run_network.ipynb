# %%
import numpy as np
from pygenn import GeNNModel
from pygenn.neuron_models import SpikeSourceArray

# %%
model = GeNNModel("float", "test", backend="single_threaded_cpu")

node_id = "0"
size = 1

pop = model.add_neuron_population(
    node_id,
    size,
    "SpikeSourceArray",
    {},
    {"startSpike": np.array([0], dtype=np.uint32),
        "endSpike": np.array([0], dtype=np.uint32)}
)
print(pop.extra_global_params["spikeTimes"])

# %%
input_to_network = SpikeSourceArray()

# %%
input_to_network.extra_global_params
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 input_to_network.extra_global_params
#
# AttributeError: 'pygenn._genn.NeuronModelBase' object has no attribute 'extra_global_params'
